# %%
from consolidated_bp_kay.CBP_Bioreactor_BioSTEAM.CBP_Biorefinery import cELLUgsa,cbp_reactor, cbp, CBP_Modified_Biorefinery,
# Out:
#   Cell In[2], line 1
#     from consolidated_bp_kay.CBP_Bioreactor_BioSTEAM.CBP_Biorefinery import cELLUgsa,cbp_reactor, cbp, CBP_Modified_Biorefinery,
#                                                                                                                                  ^
# SyntaxError: trailing comma not allowed without surrounding parentheses
