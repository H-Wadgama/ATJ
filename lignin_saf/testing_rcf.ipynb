# %%
import biosteam as bst
from lignin_saf.ligsaf_chemicals import create_chemicals
from lignin_saf.ligsaf_settings import feed_parameters

chems = create_chemicals()
bst.settings.set_thermo(chems)
bst.settings.CEPCI = 541.7   # 2016 USD basis

# Poplar group must be defined before creating any stream that references it
chems.define_group(
    name='Poplar',
    IDs=['Glucan', 'Xylan', 'Arabinan', 'Mannan', 'Galactan',
         'Sucrose', 'Lignin', 'Acetate', 'Extract', 'Ash'],
    composition=[0.464, 0.134, 0.002, 0.037, 0.014,
                 0.001, 0.285, 0.035, 0.016, 0.012],
    wt=True
)

poplar_in = bst.Stream('Poplar_In',
                       Poplar=feed_parameters['flow'] * 1e3,
                       Water=feed_parameters['moisture'] * feed_parameters['flow'] * 1e3,
                       phase='l', units='kg/d')

# %%
from lignin_saf.ligsaf_system import create_rcf_system                                                                                                        
rcf_system = create_rcf_system(ins=poplar_in)

# %%
rcf_system.simulate()
# Out:
# c:\Users\mmw6427\AppData\Local\anaconda3\envs\pyfuel\lib\site-packages\thermosteam\equilibrium\bubble_point.py:120: RuntimeWarning: Hydrogen has no defined Dortmund groups; functional group interactions are ignored
#   self.gamma = thermo.Gamma(chemicals)
# c:\Users\mmw6427\AppData\Local\anaconda3\envs\pyfuel\lib\site-packages\thermosteam\equilibrium\bubble_point.py:120: RuntimeWarning: Methane has no defined Dortmund groups; functional group interactions are ignored
#   self.gamma = thermo.Gamma(chemicals)
# c:\Users\mmw6427\AppData\Local\anaconda3\envs\pyfuel\lib\site-packages\thermosteam\equilibrium\dew_point.py:129: RuntimeWarning: Methane has no defined Dortmund groups; functional group interactions are ignored
#   self.gamma = thermo.Gamma(chemicals)
# C:\Users\mmw6427\OneDrive - The Pennsylvania State University\Shi_Wadgama_shared\Models\ATJSPK\lignin_saf\ligsaf_units.py:299: CostWarning: <SolvolysisReactor: RCF103_S> Vertical vessel weight (2.162e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# C:\Users\mmw6427\OneDrive - The Pennsylvania State University\Shi_Wadgama_shared\Models\ATJSPK\lignin_saf\ligsaf_units.py:299: CostWarning: <SolvolysisReactor: RCF103_S> Vertical vessel length (66.13 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# C:\Users\mmw6427\OneDrive - The Pennsylvania State University\Shi_Wadgama_shared\Models\ATJSPK\lignin_saf\ligsaf_units.py:519: CostWarning: <HydrogenolysisReactor: RCF106_H> Vertical vessel weight (2.257e+06 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# C:\Users\mmw6427\OneDrive - The Pennsylvania State University\Shi_Wadgama_shared\Models\ATJSPK\lignin_saf\ligsaf_units.py:519: CostWarning: <HydrogenolysisReactor: RCF106_H> Vertical vessel length (56.24 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\mmw6427\AppData\Local\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1183: CostWarning: <IsentropicCompressor: PUMP108> power (2.478e-12 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# c:\Users\mmw6427\AppData\Local\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <Flash: FLASH109> Vertical vessel weight (2277 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   return method(pressure, diameter, length)
# c:\Users\mmw6427\AppData\Local\anaconda3\envs\pyfuel\lib\site-packages\biosteam\units\design_tools\pressure_vessel.py:104: CostWarning: <Flash: FLASH109> Vertical vessel length (9.5 ft) is out of bounds (12 to 40 ft) for cost correlation
#   return method(pressure, diameter, length)
# C:\Users\mmw6427\OneDrive - The Pennsylvania State University\Shi_Wadgama_shared\Models\ATJSPK\lignin_saf\ligsaf_units.py:838: CostWarning: <PSA: PSA111> Vertical vessel weight (1394 lb) is out of bounds (4200 to 1e+06 lb) for cost correlation
#   self._vertical_vessel_design(
# C:\Users\mmw6427\OneDrive - The Pennsylvania State University\Shi_Wadgama_shared\Models\ATJSPK\lignin_saf\ligsaf_units.py:838: CostWarning: <PSA: PSA111> Vertical vessel length (7.869 ft) is out of bounds (12 to 40 ft) for cost correlation
#   self._vertical_vessel_design(
# c:\Users\mmw6427\AppData\Local\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:1183: CostWarning: <IsentropicCompressor: vaccuum_pump> power (988.4 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self._cost(**cost_kwargs) if cost_kwargs else self._cost()
# C:\Users\mmw6427\OneDrive - The Pennsylvania State University\Shi_Wadgama_shared\Models\ATJSPK\lignin_saf\ligsaf_units.py:883: CostWarning: <IsentropicCompressor: vaccuum_pump> power (988.4 hp) is out of bounds (10 to 750 hp) for cost correlation
#   self.vaccuum_pump._cost()
# c:\Users\mmw6427\AppData\Local\anaconda3\envs\pyfuel\lib\site-packages\biosteam\_unit.py:921: RuntimeWarning: the purchase cost item, 'Adsorbent cost', has no defined bare-module factor in the 'PSA.F_BM' dictionary; bare-module factor now has a default value of 1
#   warn(f"the purchase cost item, '{name}', has "

# %%
rcf_system.show()
# Out:
# System: RCF_System
# Highest convergence error among components in recycle
# streams {HX117-0, PUMP112-0} after 3 loops:
# - flow rate   2.08e-06 kmol/hr (0.032%)
# - temperature 4.54e-03 K (0.0015%)
# ins...
# [0] RCF_Catalyst
#     phase: 'l', T: 298.15 K, P: 101325 Pa
#     flow (kmol/hr): NiC  2.28
# [1] Poplar_In
#     phase: 'l', T: 298.15 K, P: 101325 Pa
#     flow (kmol/hr): Water    925
#                     Sucrose  0.243
#                     Extract  7.4
#                     Acetate  48.6
#                     Ash      1e+03
#                     Lignin   156
#                     Glucan   238
#                     ...      112
# [2] Meoh_in
#     phase: 'l', T: 298.15 K, P: 101325 Pa
#     flow (kmol/hr): Water     2.26e+03
#                     Methanol  73.9
# [3] Hydrogen_In
#     phase: 'g', T: 353.15 K, P: 3e+06 Pa
#     flow (kmol/hr): Hydrogen  771
# outs...
# [0] RCF_WW
#     phase: 'l', T: 408.71 K, P: 101325 Pa
#     flow (kmol/hr): Water     2.26e+03
#                     Acetate   48.5
#                     Methanol  8.15
# [1] s19
#     phase: 'l', T: 298.15 K, P: 101325 Pa
#     flow: 0
# [2] Carbohydrate_Pulp
#     phase: 'l', T: 298.15 K, P: 101325 Pa
#     flow (kmol/hr): Water     925
#                     Sucrose   0.243
#                     Ash       1e+03
#                     Lignin    46.8
#                     Glucan    215
#                     Xylan     78.6
#                     Arabinan  0.505
#                     ...       13.1
# [3] RCF_Oil
#     phase: 'l', T: 400 K, P: 101325 Pa
#     flow (kmol/hr): Extract         7.4
#                     Glucan          23.8
#                     Xylan           5.92
#                     Arabinan        0.757
#                     Mannan          9.51
#                     Galactan        3.6
#                     Propylguaiacol  25
#                     ...             39
# [4] Purge_Light_Gases
#     phase: 'g', T: 503.68 K, P: 101326 Pa
#     flow (kmol/hr): Water     0.08
#                     CO        50.9
#                     Acetate   0.000295
#                     Methanol  5.58
#                     Hydrogen  258
#                     Methane   31.2
